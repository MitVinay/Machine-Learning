# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Feature Construction

# %% [markdown]
# In this section, We create new features based on the existing features.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ## Objective
#
# We will combine SiSp and Parent into one column Family
# - 0 -> Alone
# - 1 -> Small
# - 2 -> Large

# %%
df = pd.read_csv("train.csv", usecols = ['Age', "Pclass", 'SibSp', 'Parch', 'Survived'])

# %%
df.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch
# 0         0       3  22.0      1      0
# 1         1       1  38.0      1      0
# 2         1       3  26.0      0      0
# 3         1       1  35.0      1      0
# 4         0       3  35.0      0      0

# %%
df.isnull().mean()
# Out:
# Survived    0.000000
# Pclass      0.000000
# Age         0.198653
# SibSp       0.000000
# Parch       0.000000
# dtype: float64

# %%
df.dropna(inplace = True)

# %%
df.isnull().mean()
# Out:
# Survived    0.0
# Pclass      0.0
# Age         0.0
# SibSp       0.0
# Parch       0.0
# dtype: float64

# %%
df.shape
# Out:
# (714, 5)

# %%
df.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch
# 0         0       3  22.0      1      0
# 1         1       1  38.0      1      0
# 2         1       3  26.0      0      0
# 3         1       1  35.0      1      0
# 4         0       3  35.0      0      0
