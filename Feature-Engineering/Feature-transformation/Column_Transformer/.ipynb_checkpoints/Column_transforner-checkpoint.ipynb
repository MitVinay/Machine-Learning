# %% [markdown]
# # Why do we need column transformer
#
# ![image.png](attachment:image.png)
# If we see in the above photo attached, we have three types of data
# - Age: Numerical
# - city, Gender : Nominal Categorical data
# - review: Ordinal Categorical Data
#
# If we see we have to perform different operation to get subsequent categorical data. This makes it very hectic and non-efficient. To resolve this columnTransformer was introducted which is very efficient and effective to use.
