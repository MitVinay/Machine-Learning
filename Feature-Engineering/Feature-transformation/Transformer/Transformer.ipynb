# %% [markdown]
# # Reason for using function transformation
#
# When we use this function transformation, It transforms the pdf of the variable to Normal Distribution.

# %% [markdown]
# # Types of Transformer
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # How to find if the data is Normal?
#
# ## Method 1
# ![image.png](attachment:image.png)
#
# ## Method 2
# if the value is 0, then it is normal. If positive and negative then it is skewed.
# ![image-2.png](attachment:image-2.png)
#
# ## Method 3
# ![image-3.png](attachment:image-3.png)
