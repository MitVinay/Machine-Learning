# %% [markdown]
# There are two types of KNN imputer as follows:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
