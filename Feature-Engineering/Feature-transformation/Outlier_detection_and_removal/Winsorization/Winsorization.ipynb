# %% [markdown]
# ## Introduction

# %% [markdown]
# ### What is Percentile?
# - Suppose the maximum marks is 95, then 95 is 100 percentile. Below value 95 we have all the values.
# - Suppose the minimum marks is 0, then 0 is 0 percentile. Because no value is below this value.
# - 50 percentile is called median.

# %% [markdown]
# In this method, we consider a threshold. For exmaple. Below 1 percentile and above 99 percentile. Every this is a outlier.

# %% [markdown]
# When the outlier is detected we either remove it or cap it. In this approach the capping is called winsorization.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("weight-height.csv")

# %%
df.shape
# Out:
# (10000, 3)

# %%
df.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
df.isnull().mean()
# Out:
# Gender    0.0
# Height    0.0
# Weight    0.0
# dtype: float64

# %%
plt.figure(figsize = (16, 5))
plt.subplot(1, 2, 1)
sns.distplot(df['Height'])

plt.subplot(1, 2, 2)
sns.distplot(df['Weight'])

plt.show()
# Out:
# /var/folders/_m/_0hzmbf1467gxwxv0b95v6_80000gn/T/ipykernel_81466/3112996515.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Height'])
# /var/folders/_m/_0hzmbf1467gxwxv0b95v6_80000gn/T/ipykernel_81466/3112996515.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Weight'])

# %%
plt.figure(figsize = (16, 5))
plt.subplot(1, 2, 1)
sns.boxplot(df['Height'])

plt.subplot(1, 2, 2)
sns.boxplot(df['Weight'])

plt.show()

# %%
df['Height'].skew()
# Out:
# 0.04936908937689031

# %%
df['Weight'].skew()
# Out:
# 0.03295450444592437

# %%
df.describe()
# Out:
#              Height        Weight
# count  10000.000000  10000.000000
# mean      66.367560    161.440357
# std        3.847528     32.108439
# min       54.263133     64.700127
# 25%       63.505620    135.818051
# 50%       66.318070    161.212928
# 75%       69.174262    187.169525
# max       78.998742    269.989699

# %%
upper_limit = df['Height'].quantile(0.99)
lower_limit = df['Height'].quantile(0.01)

# %%
print("Upper Limit = ", upper_limit)
print("Lower Limit = ", lower_limit)
# Out:
# Upper Limit =  74.7857900583366
# Lower Limit =  58.13441158671655

# %%
df[(df['Height'] >= upper_limit) | (df['Height'] <= lower_limit)]
# Out:
#       Gender     Height      Weight
# 23      Male  75.205974  228.761781
# 190     Male  76.709835  235.035419
# 197     Male  75.944460  231.924749
# 202     Male  75.140821  224.124271
# 215     Male  74.795375  232.635403
# ...      ...        ...         ...
# 9761  Female  56.975279   90.341784
# 9825  Female  55.979198   85.417534
# 9895  Female  57.740192   93.652957
# 9904  Female  57.028857  101.202551
# 9978  Female  57.375759  114.192209
#
# [200 rows x 3 columns]

# %% [markdown]
# # Trimming

# %%
new_df = df[(df['Height'] <= upper_limit) & (df['Height'] >= lower_limit)]

# %%
new_df.sample(5)
# Out:
#       Gender     Height      Weight
# 3350    Male  68.295778  171.916742
# 5975  Female  60.257493  110.101140
# 8586  Female  68.222664  161.041578
# 6765  Female  68.823692  175.031808
# 593     Male  65.544076  171.980331

# %%
plt.figure(figsize = (16, 5))
plt.subplot(1, 2, 1)
sns.distplot(df['Height'])

plt.subplot(1, 2, 2)
sns.distplot(new_df['Height'])

plt.show()
# Out:
# /var/folders/_m/_0hzmbf1467gxwxv0b95v6_80000gn/T/ipykernel_81466/1013569668.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Height'])
# /var/folders/_m/_0hzmbf1467gxwxv0b95v6_80000gn/T/ipykernel_81466/1013569668.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['Height'])

# %%
plt.figure(figsize = (16, 5))
plt.subplot(1, 2, 1)
sns.boxplot(df['Height'])

plt.subplot(1, 2, 2)
sns.boxplot(new_df['Height'])

plt.show()

# %%
new_df['Height'].describe()`
# Out:
# count    9800.000000
# mean       66.364366
# std         3.645075
# min        58.134496
# 25%        63.577162
# 50%        66.318070
# 75%        69.119896
# max        74.785714
# Name: Height, dtype: float64

# %%
df['Height'].describe()
# Out:
# count    10000.000000
# mean        66.367560
# std          3.847528
# min         54.263133
# 25%         63.505620
# 50%         66.318070
# 75%         69.174262
# max         78.998742
# Name: Height, dtype: float64

# %% [markdown]
# # Capping / Winsorization

# %%
new_df_capping = df.copy()

# %%
new_df_capping['Height'] = np.where(new_df_capping['Height'] > upper_limit, upper_limit,
                                   np.where(new_df_capping['Height'] < lower_limit, lower_limit,
                                           new_df_capping['Height']))

# %%
plt.figure(figsize = (16, 5))
plt.subplot(1, 2, 1)
sns.distplot(df['Height'])

plt.subplot(1, 2, 2)
sns.distplot(new_df_capping['Height'])

plt.show()
# Out:
# /var/folders/_m/_0hzmbf1467gxwxv0b95v6_80000gn/T/ipykernel_81466/4227324578.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Height'])
# /var/folders/_m/_0hzmbf1467gxwxv0b95v6_80000gn/T/ipykernel_81466/4227324578.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df_capping['Height'])

# %%
plt.figure(figsize = (16, 5))
plt.subplot(1, 2, 1)
sns.boxplot(df['Height'])

plt.subplot(1, 2, 2)
sns.boxplot(new_df_capping['Height'])

plt.show()

# %%
new_df_capping['Height'].describe()
# Out:
# count    10000.000000
# mean        66.366281
# std          3.795717
# min         58.134412
# 25%         63.505620
# 50%         66.318070
# 75%         69.174262
# max         74.785790
# Name: Height, dtype: float64
