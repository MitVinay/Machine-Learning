# %% [markdown]
# # Univariate Analysis
# When we do independent analysis of the column or variable of the data set one by one. That is called univariate analysis.

# %% [markdown]
# There are two types of data in the Dataset:
# - Numerical Data - Example: Age, Height etc
# - Categorical Data - Example: Nationality, College name etc

# %% [markdown]
# # Performing Univariate Analysis on Titanic Dataset
# - Survived: Target Variable
# - Pclass: Passenger class- 1 was the elite and 3 was the cheapest
# - Sibsp: Were there any sibling or spouse traveling with the passenger.
# - Parch: Parent or child, where there any parent or child with the passenger.
# - Cabin: Only first class passenger has cabin allocated.
# - Embarked: There was three station or port from where the traveller boarded. Notation were "C", "S", "Q"

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("train.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # 1. Categorical Data

# %% [markdown]
# ## a. Count Plot

# %% [markdown]
# ### Survived

# %%
# sns.countplot(df['Survived'])
df['Survived'].value_counts().plot(kind = "bar")
# Out:
# <Axes: >

# %%
# Pclass
df['Pclass'].value_counts().plot(kind = "bar")
# Out:
# <Axes: >

# %%
# Gender
df['Sex'].value_counts().plot(kind = "bar")
# Out:
# <Axes: >

# %% [markdown]
# ## Pie chart

# %%
df['Survived'].value_counts().plot(kind = "pie", autopct = "%0.2f")
# Out:
# <Axes: ylabel='Survived'>

# %%
df['Pclass'].value_counts().plot(kind = "pie", autopct = "%0.2f")
# Out:
# <Axes: ylabel='Pclass'>

# %%
df['Sex'].value_counts().plot(kind = "pie", autopct = "%0.2f")
# Out:
# <Axes: ylabel='Sex'>

# %% [markdown]
# # 2. Numerical Data

# %% [markdown]
# ## a. Histogram

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df['Age'])
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## b. Distplot
# The line is called Kernal Distance Estimation. The line is generallly called pdf.

# %%
sns.distplot(df['Age'])
# Out:
# /var/folders/_m/_0hzmbf1467gxwxv0b95v6_80000gn/T/ipykernel_19896/3255828239.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# ## c. Boxplot
# Box plot gives you 5 number summary.

# %%
sns.boxplot(df['Fare'])
# Out:
# <Axes: >

# %%
df['Age'].skew()
# Out:
# 0.38910778230082704

# %% [markdown]
# The positive values tells that the pdf is positively skewed and negative values tells that negatively skewed. Also 0 values tells that the pdf is perfectly symmeterical.

# %% [markdown]
# #
