# %% [markdown]
# ## Multiple Linear Regression

# %% [markdown]
# When Input column is more than 1.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# These coefficients are like weights, More the weight more is the role of that paramter.

# %%
from sklearn.datasets import make_regression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go

# %%
X, y = make_regression(n_samples = 100, n_features = 2, n_informative = 2, n_targets = 1, noise = 50)

# %%
df = pd.DataFrame({'feature1':X[:, 0], 'feature2' : X[:, 1], 'target': y})

# %%
df.head()
# Out:
#    feature1  feature2     target
# 0 -0.350846  1.711994 -22.123869
# 1  0.034843 -1.749153  76.650347
# 2  1.337193 -0.430979  80.711929
# 3  1.320284 -0.063717  98.268296
# 4 -0.734422 -0.471196 -52.796705

# %%
fig = px.scatter_3d(df, x = 'feature1', y = "feature2", z = 'target')

fig.show()
# Out:
# <div>                            <div id="f547e558-b53e-4540-adb5-34be3a1d45fb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f547e558-b53e-4540-adb5-34be3a1d45fb")) {                    Plotly.newPlot(                        "f547e558-b53e-4540-adb5-34be3a1d45fb",                        [{"hovertemplate":"feature1=%{x}<br>feature2=%{y}<br>target=%{z}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":[-0.35084555491533675,0.0348432457942964,1.3371926945675945,1.32028392552489,-0.7344220962436457,1.547052547415994,-1.103289123545539,0.9366032419665281,-1.4141081815511427,0.3316516617971727,-0.11800597954300088,1.4885825645854256,-0.8282016817152411,-0.318796018564191,-1.565959842036179,-1.96179641823178,-0.056295825580400055,0.38525404462845453,-0.15327820572284293,-0.9189531056228954,2.613693288863451,0.16639479038116706,0.43233289765750893,1.0021637702929638,1.6318793648693088,0.4200793670611413,-1.2152238467310752,1.6780274618250708,1.7237710546912282,-1.016820971612392,0.3187513455202967,-0.12439078350305903,-0.148100552851227,0.012144263173938517,0.4985994245861097,0.955392536850137,1.188871472437101,-2.7577157246041857,0.06517432379959585,0.7028246331704137,-1.0873986343390338,0.6725763225961366,0.6810972196407836,-0.30727210291943136,0.7260819101718025,-1.1135510325284768,0.17922924355155567,0.4152770925004923,-1.0225254316984564,0.07166196258999435,-0.1904030033725398,0.1295944214736583,-0.4815037026463879,-1.2592862351122376,-0.3786431898928988,0.13217565727926026,0.225605411858427,1.2524861069669093,1.0906641334067821,-0.7837849394974221,-0.40203910620904254,-0.6301840790272958,-0.030618759611649855,1.0786928821822912,0.011172737003962298,-1.3678345558011114,-2.0362005374024275,-0.028254548714547485,1.1206864430559735,-0.08388859998516998,0.09367322499824916,0.4148781366528987,-0.3991314461236407,1.3659383978306356,0.719945355110666,-1.449075947190261,0.7308802903842412,-0.4870045111213041,0.4841595946499978,-0.422549531925866,-0.6956711761799204,-1.0071808488212877,0.7155734507795307,-1.551360532364936,1.4810299056256353,-0.6098434843798536,-0.555005508251787,-0.5301363308595674,-0.17046019196291343,-1.346807298325917,-0.7136296092763139,0.40384705162113027,-1.4953246421552562,1.2923598333860455,-0.21228471565036408,0.44535258429087654,-0.44014209348807976,0.8172375003255963,-1.4961361152097974,0.42458867947443957],"y":[1.7119938717039271,-1.7491528915882342,-0.43097886238090327,-0.0637169682179995,-0.4711957864042493,0.05904193371079197,0.5626514778168291,-1.5835876919610277,1.149598270716154,-0.24591614434793396,-0.4534451320957035,-0.9152010639467661,0.14377868769646113,-0.9352406977779759,0.3909952922373474,-1.037282050252161,-0.6451490089939019,0.8074269637170184,-2.1512383664509875,-0.44961846025290214,-1.622570218276702,0.6185506619764171,-1.4071229007882216,-1.0134591524552383,1.314857130022768,-1.4519406398686325,0.5345338913405903,-0.2353138429958966,-2.5205648298474768,1.5683860562559635,0.03581798764315503,-1.2737911698621425,2.5626513505848134,0.43926539332522385,0.09499150719066142,0.8272094261045934,0.16198960284165057,1.0122334759125318,-2.050649450306803,1.017352708919574,-0.11149437451645133,-0.3309452551268079,2.289168123328527,0.0895663790763488,-0.5787209566920736,-1.2067240153180612,-0.6311110099259741,1.4573466374222,-0.7329041489791533,0.5150493618794425,-1.7447600910748347,0.48661216774912047,-1.0677137796344909,-1.8120941563073976,1.145105395038765,-1.37001739475908,0.14121075758062562,0.8872759233542667,0.9814376088437246,0.3706302525059143,-0.38984511529622756,-1.7289886093213942,2.9341629499762463,-0.09610356019133841,-0.10011279485824798,-0.1164326604053900 ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,
                                                   y,
                                                   test_size = 0.2,
                                                   random_state = 2)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 31.959224721966564

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 1479.3840381218502

# %%
r2_score(y_test, y_pred)
# Out:
# 0.7509744659662898

# %%
x = np.linspace(-5, 5, 10)
y = np.linspace(-5, 5, 10)
xGrid, yGrid = np.meshgrid(y, x)

z_final = lr.predict(final).reshape(10,10)

z = z_final

final = np.vstack((xGrid.ravel().reshape(1,100),yGrid.ravel().reshape(1,100))).T
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 5
#       2 y = np.linspace(-5, 5, 10)
#       3 xGrid, yGrid = np.meshgrid(y, x)
# ----> 5 z_final = lr.predict(final).reshape(10,10)
#       7 z = z_final
#       9 final = np.vstack((xGrid.ravel().reshape(1,100),yGrid.ravel().reshape(1,100))).T
#
# NameError: name 'final' is not defined

# %%
fig = px.scatter_3d(df, x='feature1', y='feature2', z='target')

fig.add_trace(go.Surface(x = x, y = y, z =z ))

fig.show()

# %%
lr.coef_
# Out:
# array([77.61752585,  5.96589903])

# %%
lr.intercept_
# Out:
# 2.2686173104448546
