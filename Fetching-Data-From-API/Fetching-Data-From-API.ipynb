# %% [markdown]
# # Importing Library

# %%
import pandas as pd
import requests

# %%
# Passing the API URL
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %% [markdown]
# General Idea: Python using requests library hitting request to api http, in return api gives back the data based
# on the request.
# Reponse meaning
# 1. 200 - Got back the expected response
# 2. 404 - Page not available
# 3. 500 - Server down

# %% [markdown]
# # Fetching Json and converting it to Data Frame

# %%
# Converting the data in JSON
temp_df = pd.DataFrame(response.json()['results'])[['id', 'title', 'overview', 'release_date', 'popularity',
                                                 'vote_average', 'vote_count']]

# %%
df.head(5)
# Out:
#       id                        title  \
# 0    238                The Godfather
# 1    278     The Shawshank Redemption
# 2    240        The Godfather Part II
# 3    424             Schindler's List
# 4  19404  Dilwale Dulhania Le Jayenge
#
#                                             overview release_date  popularity  \
# 0  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     160.639
# 1  Framed in the 1940s for the double murder of h...   1994-09-23     137.689
# 2  In the continuing saga of the Corleone crime f...   1974-12-20      82.973
# 3  The true story of how businessman Oskar Schind...   1993-12-15      83.051
# 4  Raj is a rich, carefree, happy-go-lucky second...   1995-10-20      44.336
#
#    vote_average  vote_count
# 0         8.708       19016
# 1         8.705       25006
# 2         8.590       11480
# 3         8.571       14821
# 4         8.546        4286

# %% [markdown]
# # Iterating all pages

# %%
df = pd.DataFrame()

# %%
for i in range(1, 4):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id', 'title', 'overview', 'release_date', 'popularity',
                                                 'vote_average', 'vote_count']]
    df = df.append(temp_df, ignore_index = True)
# Out:
# /var/folders/_m/_0hzmbf1467gxwxv0b95v6_80000gn/T/ipykernel_70224/1445349702.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df, ignore_index = True)
# /var/folders/_m/_0hzmbf1467gxwxv0b95v6_80000gn/T/ipykernel_70224/1445349702.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df, ignore_index = True)
# /var/folders/_m/_0hzmbf1467gxwxv0b95v6_80000gn/T/ipykernel_70224/1445349702.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df, ignore_index = True)

# %%
df
# Out:
#         id                                              title  \
# 0      238                                      The Godfather
# 1      278                           The Shawshank Redemption
# 2      240                              The Godfather Part II
# 3      424                                   Schindler's List
# 4    19404                        Dilwale Dulhania Le Jayenge
# 5      389                                       12 Angry Men
# 6      129                                      Spirited Away
# 7   496243                                           Parasite
# 8      155                                    The Dark Knight
# 9      497                                     The Green Mile
# 10  372058                                         Your Name.
# 11     680                                       Pulp Fiction
# 12     122      The Lord of the Rings: The Return of the King
# 13      13                                       Forrest Gump
# 14     429                     The Good, the Bad and the Ugly
# 15     769                                         GoodFellas
# 16   12477                             Grave of the Fireflies
# 17     637                                  Life Is Beautiful
# 18     346                                      Seven Samurai
# 19   11216                                    Cinema Paradiso
# 20  667257                                  Impossible Things
# 21     550                                         Fight Club
# 22  696374                                  Gabriel's Inferno
# 23     539                                             Psycho
# 24     598                                        City of God
# 25     311                        Once Upon a Time in America
# 26  724089                         Gabriel's Inferno: Part II
# 27  372754                           Dou kyu sei – Classmates
# 28     510                    One Flew Over the Cuckoo's Nest
# 29  157336                                       Interstellar
# 30  568332              Taylor Swift: Reputation Stadium Tour
# 31  761053                        Gabriel's Inferno: Part III
# 32  324857                  Spider-Man: Into the Spider-Verse
# 33   14537                                           Harakiri
